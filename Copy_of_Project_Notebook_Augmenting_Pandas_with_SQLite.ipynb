# %% [markdown]
# # Project Notebook: Augmenting Pandas with SQLite

# %% [markdown]
# ## Question 1: Introduction

# %% [markdown]
# In this session, we explored a few different ways to work with larger datasets in pandas. In this guided project, we'll practice using some of the techniques we learned to analyze startup investments from Crunchbase.com.
#
# Every year, thousands of startup companies raise financing from investors. Each time a startup raises money, we refer to the event as a fundraising round. Crunchbase is a website that crowdsources information on the fundraising rounds of many startups. The Crunchbase user community submits, edits, and maintains most of the information in Crunchbase.
#
# In return, Crunchbase makes the data available through a Web application and a fee-based API. Before Crunchbase switched to the paid API model, multiple groups crawled the site and released the data online. Because the information on the startups and their fundraising rounds is always changing, the data set we'll be using isn't completely up to date.
#
# Throughout this project, we'll practice working with different memory constraints. In this step, let's assume we only have 10 megabytes of available memory. While crunchbase-investments.csv (https://bit.ly/3BPcobU) consumes 10.3 megabytes of disk space, we know from earlier lessons that pandas often requires 4 to 6 times amount of space in memory as the file does on disk (especially when there's many string columns).
#
#
# **Tasks**
#
# * Because the data set contains over 50,000 rows, you'll need to read the data set into dataframes using 5,000 row chunks to ensure that each chunk consumes much less than 10 megabytes of memory.
# * Across all of the chunks, become familiar with:
# 1. Each column's missing value counts.
# 2. Each column's memory footprint.
# 3. The total memory footprint of all of the chunks combined.
# 4. Which column(s) we can drop because they aren't useful for analysis.

# %%
# Your code goes here
# Dataset URL = https://bit.ly/3BPcobU

import pandas as pd

import matplotlib.pyplot as plt

import sqlite3

import numpy as np

augment_df = pd.read_csv("https://bit.ly/3BPcobU",encoding = 'unicode_escape')
print(augment_df.shape)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (52870, 20)

# %%
# checking missing value counts
augment_df.isnull().sum()
# Out:
# company_permalink             1
# company_name                  1
# company_category_code       643
# company_country_code          1
# company_state_code          492
# company_region                1
# company_city                533
# investor_permalink            2
# investor_name                 2
# investor_category_code    50427
# investor_country_code     12001
# investor_state_code       16809
# investor_region               2
# investor_city             12480
# funding_round_type            3
# funded_at                     3
# funded_month                  3
# funded_quarter                3
# funded_year                   3
# raised_amount_usd          3599
# dtype: int64

# %%
# checking Each column's memory footprint.
chrunch_iter = pd.read_csv("https://bit.ly/3BPcobU",chunksize=5000,encoding = 'unicode_escape')
for chunkx in chrunch_iter:  
  print(chunkx.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4948 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4947 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4936 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  2443 non-null   object
#  10  investor_country_code   4222 non-null   object
#  11  investor_state_code     3629 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4100 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4347 non-null   float64
# dtypes: float64(1), int64(1), object(18)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 5000 to 9999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4949 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4957 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4955 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4739 non-null   object
#  11  investor_state_code     4286 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4687 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4761 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 10000 to 14999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4918 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4944 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4956 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4729 non-null   object
#  11  investor_state_code     4192 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4686 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4779 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 15000 to 19999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4943 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4964 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4956 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4761 non-null   object
#  11  investor_state_code     4286 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4726 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4701 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 20000 to 24999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4931 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4960 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4959 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4648 non-null   object
#  11  investor_state_code     3884 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4566 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4757 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 25000 to 29999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4939 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4961 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4967 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4782 non-null   object
#  11  investor_state_code     4268 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4762 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4794 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 30000 to 34999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       4999 non-null   object
#  1   company_name            4999 non-null   object
#  2   company_category_code   4912 non-null   object
#  3   company_country_code    4999 non-null   object
#  4   company_state_code      4965 non-null   object
#  5   company_region          4999 non-null   object
#  6   company_city            4958 non-null   object
#  7   investor_permalink      4998 non-null   object
#  8   investor_name           4998 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4687 non-null   object
#  11  investor_state_code     4078 non-null   object
#  12  investor_region         4998 non-null   object
#  13  investor_city           4661 non-null   object
#  14  funding_round_type      4997 non-null   object
#  15  funded_at               4997 non-null   object
#  16  funded_month            4997 non-null   object
#  17  funded_quarter          4997 non-null   object
#  18  funded_year             4997 non-null   float64
#  19  raised_amount_usd       4713 non-null   float64
# dtypes: float64(3), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 35000 to 39999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4917 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4935 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4945 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   4733 non-null   object
#  11  investor_state_code     4225 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           4666 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4632 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 40000 to 44999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4925 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4950 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4950 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   3568 non-null   object
#  11  investor_state_code     3213 non-null   object
#  12  investor_region         5000 non-null   object
#  13  investor_city           3536 non-null   object
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4676 non-null   float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 45000 to 49999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       5000 non-null   object
#  1   company_name            5000 non-null   object
#  2   company_category_code   4985 non-null   object
#  3   company_country_code    5000 non-null   object
#  4   company_state_code      4954 non-null   object
#  5   company_region          5000 non-null   object
#  6   company_city            4930 non-null   object
#  7   investor_permalink      5000 non-null   object
#  8   investor_name           5000 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   0 non-null      float64
#  11  investor_state_code     0 non-null      float64
#  12  investor_region         5000 non-null   object
#  13  investor_city           0 non-null      float64
#  14  funding_round_type      5000 non-null   object
#  15  funded_at               5000 non-null   object
#  16  funded_month            5000 non-null   object
#  17  funded_quarter          5000 non-null   object
#  18  funded_year             5000 non-null   int64
#  19  raised_amount_usd       4531 non-null   float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 781.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2870 entries, 50000 to 52869
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       2870 non-null   object
#  1   company_name            2870 non-null   object
#  2   company_category_code   2860 non-null   object
#  3   company_country_code    2870 non-null   object
#  4   company_state_code      2841 non-null   object
#  5   company_region          2870 non-null   object
#  6   company_city            2825 non-null   object
#  7   investor_permalink      2870 non-null   object
#  8   investor_name           2870 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   0 non-null      float64
#  11  investor_state_code     0 non-null      float64
#  12  investor_region         2870 non-null   object
#  13  investor_city           0 non-null      float64
#  14  funding_round_type      2870 non-null   object
#  15  funded_at               2870 non-null   object
#  16  funded_month            2870 non-null   object
#  17  funded_quarter          2870 non-null   object
#  18  funded_year             2870 non-null   int64
#  19  raised_amount_usd       2580 non-null   float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 448.6+ KB
# None

# %% [markdown]
# ## Findings
#
# The columns that can be dropped is investor_category_code since it have a lot of null values

# %%
# dropping investor_category_code and rows where raised amounts is null 

for chunkx in chrunch_iter:
    chunkx = chunkx.dropna(subset=['raised_amount_usd'])
    chunkx.drop(['investor_category_code'], axis=1)
print(chunkx.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2870 entries, 50000 to 52869
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   company_permalink       2870 non-null   object
#  1   company_name            2870 non-null   object
#  2   company_category_code   2860 non-null   object
#  3   company_country_code    2870 non-null   object
#  4   company_state_code      2841 non-null   object
#  5   company_region          2870 non-null   object
#  6   company_city            2825 non-null   object
#  7   investor_permalink      2870 non-null   object
#  8   investor_name           2870 non-null   object
#  9   investor_category_code  0 non-null      float64
#  10  investor_country_code   0 non-null      float64
#  11  investor_state_code     0 non-null      float64
#  12  investor_region         2870 non-null   object
#  13  investor_city           0 non-null      float64
#  14  funding_round_type      2870 non-null   object
#  15  funded_at               2870 non-null   object
#  16  funded_month            2870 non-null   object
#  17  funded_quarter          2870 non-null   object
#  18  funded_year             2870 non-null   int64
#  19  raised_amount_usd       2580 non-null   float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 448.6+ KB
# None

# %%
## dropping investor_category_code and rows where raised amounts is null because they are unnecesary
for chunkx in augment_df:
  chunkx = augment_df.dropna(subset=['raised_amount_usd'])
  chunk = chunkx.drop(['investor_category_code'], axis=1) 
print(chunk.head())
# Out:
#      company_permalink company_name company_category_code  \
# 0    /company/advercar     AdverCar           advertising
# 1  /company/launchgram   LaunchGram                  news
# 2        /company/utap         uTaP             messaging
# 3    /company/zoopshop     ZoopShop              software
# 4    /company/efuneral     eFuneral                   web
#
#   company_country_code company_state_code         company_region  \
# 0                  USA                 CA                 SF Bay
# 1                  USA                 CA                 SF Bay
# 2                  USA                NaN  United States - Other
# 3                  USA                 OH               Columbus
# 4                  USA                 OH              Cleveland
#
#     company_city          investor_permalink      investor_name  \
# 0  San Francisco  /company/1-800-flowers-com  1-800-FLOWERS.COM
# 1  Mountain View        /company/10xelerator        10Xelerator
# 2            NaN        /company/10xelerator        10Xelerator
# 3       columbus        /company/10xelerator        10Xelerator
# 4      Cleveland        /company/10xelerator        10Xelerator
#
#   investor_country_code investor_state_code investor_region investor_city  \
# 0                   USA                  NY        New York      New York
# 1                   USA                  OH        Columbus      Columbus
# 2                   USA                  OH        Columbus      Columbus
# 3                   USA                  OH        Columbus      Columbus
# 4                   USA                  OH        Columbus      Columbus
#
#   funding_round_type   funded_at funded_month funded_quarter  funded_year  \
# 0           series-a  2012-10-30      2012-10        2012-Q4       2012.0
# 1              other  2012-01-23      2012-01        2012-Q1       2012.0
# 2              other  2012-01-01      2012-01        2012-Q1       2012.0
# 3              angel  2012-02-15      2012-02        2012-Q1       2012.0
# 4              other  2011-09-08      2011-09        2011-Q3       2011.0
#
#    raised_amount_usd
# 0          2000000.0
# 1            20000.0
# 2            20000.0
# 3            20000.0
# 4            20000.0

# %% [markdown]
# ## Question 2: Selecting Data Types

# %% [markdown]
# Now that we have a good sense of the missing values, let's get familiar with the column types before adding the data into SQLite.
#
# **Tasks**
#
# * Identify the types for each column.
# * Identify the numeric columns we can represent using more space efficient types.
# For text columns:
# * Analyze the unique value counts across all of the chunks to see if we can convert them to a numeric type.
# * See if we clean clean any text columns and separate them into multiple numeric columns without adding any overhead when querying.
# * Make your changes to the code from the last step so that the overall memory the data consumes stays under 10 megabytes.

# %%
# Identifying the data types of each columns.

print(chunk.dtypes)
# Out:
# company_permalink         object
# company_name              object
# company_category_code     object
# company_country_code      object
# company_state_code        object
# company_region            object
# company_city              object
# investor_permalink        object
# investor_name             object
# investor_country_code     object
# investor_state_code       object
# investor_region           object
# investor_city             object
# funding_round_type        object
# funded_at                 object
# funded_month              object
# funded_quarter            object
# funded_year              float64
# raised_amount_usd        float64
# dtype: object

# %% [markdown]
# #Identify the numeric columns we can represent using more space efficient types. For text columns:

# %%
#numeric columns identified phisically
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64','complex']

chunk_numeric = chunk.select_dtypes(include=numerics)
print("Columns that have numeric types are:",chunk_numeric.columns.tolist())
# Out:
# Columns that have numeric types are: ['funded_year', 'raised_amount_usd']

# %%
# Analyze the unique value counts across all of the chunks to see if we can convert them to a numeric type
unique_cols = [] 
for col in chunk.select_dtypes(include=['object']).columns:
  if chunk[col].nunique()/len(chunk)< 0.5:
    unique_cols.append(col)
unique_cols = list(set(unique_cols))
print(unique_cols)
# Out:
# ['company_category_code', 'funded_quarter', 'funding_round_type', 'investor_city', 'investor_state_code', 'company_region', 'company_name', 'company_permalink', 'funded_at', 'funded_month', 'company_state_code', 'company_country_code', 'investor_country_code', 'investor_region', 'investor_permalink', 'company_city', 'investor_name']

# %%
# See if we clean clean any text columns and separate them into multiple numeric columns without adding any overhead when querying.
import pandas as pd

to_drop = [] # list of columns to drop
low_unique_cols = [] # list of columns with low unique values

augment_df = pd.read_csv("https://bit.ly/3BPcobU",encoding = 'unicode_escape', chunksize = 100)
memory_usage = 0 

for chunk in augment_df:
    # leaving out the identified columns
    chunk = chunk.drop(to_drop, axis=1)
  
    chunk[chunk.select_dtypes(include=['float']).columns] = chunk.select_dtypes(include=['float']).apply(pd.to_numeric, downcast='float')
   
    chunk[chunk.select_dtypes(include=['int']).columns] = chunk.select_dtypes(include=['int']).apply(pd.to_numeric, downcast='integer')
    
    for col in low_unique_cols:
        if col in chunk.columns:
            chunk[col] = chunk[col].astype('category')
    
    chunk_memory = chunk.memory_usage(deep=True).sum() / (1024 ** 2)
    print("memory in use for the chunk is:", chunk_memory, "MB")
    
    memory_usage += chunk_memory

print("memory usage:", memory_usage, "MB")
# Out:
# memory in use for the chunk is: 0.11008930206298828 MB
# memory in use for the chunk is: 0.11035346984863281 MB
# memory in use for the chunk is: 0.10944652557373047 MB
# memory in use for the chunk is: 0.11162567138671875 MB
# memory in use for the chunk is: 0.11048221588134766 MB
# memory in use for the chunk is: 0.10946083068847656 MB
# memory in use for the chunk is: 0.11212158203125 MB
# memory in use for the chunk is: 0.10920524597167969 MB
# memory in use for the chunk is: 0.10854244232177734 MB
# memory in use for the chunk is: 0.11170101165771484 MB
# memory in use for the chunk is: 0.11116504669189453 MB
# memory in use for the chunk is: 0.10895824432373047 MB
# memory in use for the chunk is: 0.10843086242675781 MB
# memory in use for the chunk is: 0.10976028442382812 MB
# memory in use for the chunk is: 0.11037826538085938 MB
# memory in use for the chunk is: 0.11044120788574219 MB
# memory in use for the chunk is: 0.11071014404296875 MB
# memory in use for the chunk is: 0.11048412322998047 MB
# memory in use for the chunk is: 0.1095123291015625 MB
# memory in use for the chunk is: 0.1081695556640625 MB
# memory in use for the chunk is: 0.11131000518798828 MB
# memory in use for the chunk is: 0.11226177215576172 MB
# memory in use for the chunk is: 0.11123847961425781 MB
# memory in use for the chunk is: 0.1078195571899414 MB
# memory in use for the chunk is: 0.11046028137207031 MB
# memory in use for the chunk is: 0.1115121841430664 MB
# memory in use for the chunk is: 0.11155128479003906 MB
# memory in use for the chunk is: 0.11092185974121094 MB
# memory in use for the chunk is: 0.10929679870605469 MB
# memory in use for the chunk is: 0.10932159423828125 MB
# memory in use for the chunk is: 0.108795166015625 MB
# memory in use for the chunk is: 0.11194229125976562 MB
# memory in use for the chunk is: 0.1127786636352539 MB
# memory in use for the chunk is: 0.1096343994140625 MB
# memory in use for the chunk is: 0.10618209838867188 MB
# memory in use for the chunk is: 0.10857200622558594 MB
# memory in use for the chunk is: 0.10853958129882812 MB
# memory in use for the chunk is: 0.108612060546875 MB
# memory in use for the chunk is: 0.10912418365478516 MB
# memory in use for the chunk is: 0.10813331604003906 MB
# memory in use for the chunk is: 0.10904693603515625 MB
# memory in use for the chunk is: 0.10904216766357422 MB
# memory in use for the chunk is: 0.10937118530273438 MB
# memory in use for the chunk is: 0.10868167877197266 MB
# memory in use for the chunk is: 0.11086654663085938 MB
# memory in use for the chunk is: 0.11043357849121094 MB
# memory in use for the chunk is: 0.1118478775024414 MB
# memory in use for the chunk is: 0.10840225219726562 MB
# memory in use for the chunk is: 0.10965156555175781 MB
# memory in use for the chunk is: 0.1086111068725586 MB
# memory in use for the chunk is: 0.1094350814819336 MB
# memory in use for the chunk is: 0.10932064056396484 MB
# memory in use for the chunk is: 0.10941600799560547 MB
# memory in use for the chunk is: 0.10891914367675781 MB
# memory in use for the chunk is: 0.10944271087646484 MB
# memory in use for the chunk is: 0.10980987548828125 MB
# memory in use for the chunk is: 0.1096639633178711 MB
# memory in use for the chunk is: 0.10872459411621094 MB
# memory in use for the chunk is: 0.10928726196289062 MB
# memory in use for the chunk is: 0.10986614227294922 MB
# memory in use for the chunk is: 0.1096658706665039 MB
# memory in use for the chunk is: 0.11021041870117188 MB
# memory in use for the chunk is: 0.10991096496582031 MB
# memory in use for the chunk is: 0.11025810241699219 MB
# memory in use for the chunk is: 0.10943126678466797 MB
# memory in use for the chunk is: 0.10823726654052734 MB
# memory in use for the chunk is: 0.10872364044189453 MB
# memory in use for the chunk is: 0.10780143737792969 MB
# memory in use for the chunk is: 0.10871410369873047 MB
# memory in use for the chunk is: 0.10928821563720703 MB
# memory in use for the chunk is: 0.10924625396728516 MB
# memory in use for the chunk is: 0.10869789123535156 MB
# memory in use for the chunk is: 0.1093759536743164 MB
# memory in use for the chunk is: 0.1107034683227539 MB
# memory in use for the chunk is: 0.10727214813232422 MB
# memory in use for the chunk is: 0.108917236328125 MB
# memory in use for the chunk is: 0.10960769653320312 MB
# memory in use for the chunk is: 0.1096944808959961 MB
# memory in use for the chunk is: 0.1093606948852539 MB
# memory in use for the chunk is: 0.10926055908203125 MB
# memory in use for the chunk is: 0.10748481750488281 MB
# memory in use for the chunk is: 0.11436080932617188 MB
# memory in use for the chunk is: 0.10812854766845703 MB
# memory in use for the chunk is: 0.10828113555908203 MB
# memory in use for the chunk is: 0.11009788513183594 MB
# memory in use for the chunk is: 0.11114025115966797 MB
# memory in use for the chunk is: 0.11130619049072266 MB
# memory in use for the chunk is: 0.10778141021728516 MB
# memory in use for the chunk is: 0.10882759094238281 MB
# memory in use for the chunk is: 0.10909366607666016 MB
# memory in use for the chunk is: 0.11021232604980469 MB
# memory in use for the chunk is: 0.10958290100097656 MB
# memory in use for the chunk is: 0.10870552062988281 MB
# memory in use for the chunk is: 0.10832691192626953 MB
# memory in use for the chunk is: 0.10943412780761719 MB
# memory in use for the chunk is: 0.10974979400634766 MB
# memory in use for the chunk is: 0.11004447937011719 MB
# memory in use for the chunk is: 0.10933113098144531 MB
# memory in use for the chunk is: 0.10898113250732422 MB
# memory in use for the chunk is: 0.10851001739501953 MB
# memory in use for the chunk is: 0.10997295379638672 MB
# memory in use for the chunk is: 0.1082143783569336 MB
# memory in use for the chunk is: 0.1095113754272461 MB
# memory in use for the chunk is: 0.1075124740600586 MB
# memory in use for the chunk is: 0.11003303527832031 MB
# memory in use for the chunk is: 0.11060428619384766 MB
# memory in use for the chunk is: 0.10973930358886719 MB
# memory in use for the chunk is: 0.11026382446289062 MB
# memory in use for the chunk is: 0.10831928253173828 MB
# memory in use for the chunk is: 0.10965442657470703 MB
# memory in use for the chunk is: 0.10965824127197266 MB
# memory in use for the chunk is: 0.1110982894897461 MB
# memory in use for the chunk is: 0.10986900329589844 MB
# memory in use for the chunk is: 0.11026763916015625 MB
# memory in use for the chunk is: 0.11028480529785156 MB
# memory in use for the chunk is: 0.10902976989746094 MB
# memory in use for the chunk is: 0.10904884338378906 MB
# memory in use for the chunk is: 0.11058807373046875 MB
# memory in use for the chunk is: 0.11034679412841797 MB
# memory in use for the chunk is: 0.1103830337524414 MB
# memory in use for the chunk is: 0.1080312728881836 MB
# memory in use for the chunk is: 0.11032676696777344 MB
# memory in use for the chunk is: 0.11008453369140625 MB
# memory in use for the chunk is: 0.10867881774902344 MB
# memory in use for the chunk is: 0.10790538787841797 MB
# memory in use for the chunk is: 0.10880851745605469 MB
# memory in use for the chunk is: 0.10865020751953125 MB
# memory in use for the chunk is: 0.10869026184082031 MB
# memory in use for the chunk is: 0.1072540283203125 MB
# memory in use for the chunk is: 0.10899162292480469 MB
# memory in use for the chunk is: 0.1094970703125 MB
# memory in use for the chunk is: 0.10906219482421875 MB
# memory in use for the chunk is: 0.10907649993896484 MB
# memory in use for the chunk is: 0.10827922821044922 MB
# memory in use for the chunk is: 0.10918045043945312 MB
# memory in use for the chunk is: 0.108612060546875 MB
# memory in use for the chunk is: 0.1096029281616211 MB
# memory in use for the chunk is: 0.11140251159667969 MB
# memory in use for the chunk is: 0.11154460906982422 MB
# memory in use for the chunk is: 0.11145782470703125 MB
# memory in use for the chunk is: 0.10968494415283203 MB
# memory in use for the chunk is: 0.10962104797363281 MB
# memory in use for the chunk is: 0.10948562622070312 MB
# memory in use for the chunk is: 0.10903739929199219 MB
# memory in use for the chunk is: 0.11032581329345703 MB
# memory in use for the chunk is: 0.10976028442382812 MB
# memory in use for the chunk is: 0.10914325714111328 MB
# memory in use for the chunk is: 0.11020278930664062 MB
# memory in use for the chunk is: 0.10819149017333984 MB
# memory in use for the chunk is: 0.10947227478027344 MB
# memory in use for the chunk is: 0.10986042022705078 MB
# memory in use for the chunk is: 0.10867977142333984 MB
# memory in use for the chunk is: 0.10811996459960938 MB
# memory in use for the chunk is: 0.1091299057006836 MB
# memory in use for the chunk is: 0.10912704467773438 MB
# memory in use for the chunk is: 0.10914421081542969 MB
# memory in use for the chunk is: 0.1095876693725586 MB
# memory in use for the chunk is: 0.11014175415039062 MB
# memory in use for the chunk is: 0.11011028289794922 MB
# memory in use for the chunk is: 0.1101217269897461 MB
# memory in use for the chunk is: 0.10968589782714844 MB
# memory in use for the chunk is: 0.1089487075805664 MB
# memory in use for the chunk is: 0.10943412780761719 MB
# memory in use for the chunk is: 0.10787773132324219 MB
# memory in use for the chunk is: 0.11006832122802734 MB
# memory in use for the chunk is: 0.10972976684570312 MB
# memory in use for the chunk is: 0.10946369171142578 MB
# memory in use for the chunk is: 0.11010074615478516 MB
# memory in use for the chunk is: 0.11019325256347656 MB
# memory in use for the chunk is: 0.11040115356445312 MB
# memory in use for the chunk is: 0.1093292236328125 MB
# memory in use for the chunk is: 0.10888195037841797 MB
# memory in use for the chunk is: 0.1085824966430664 MB
# memory in use for the chunk is: 0.11038970947265625 MB
# memory in use for the chunk is: 0.10807609558105469 MB
# memory in use for the chunk is: 0.1092519760131836 MB
# memory in use for the chunk is: 0.10868453979492188 MB
# memory in use for the chunk is: 0.10712814331054688 MB
# memory in use for the chunk is: 0.1091775894165039 MB
# memory in use for the chunk is: 0.11128997802734375 MB
# memory in use for the chunk is: 0.11119651794433594 MB
# memory in use for the chunk is: 0.10811805725097656 MB
# memory in use for the chunk is: 0.10820293426513672 MB
# memory in use for the chunk is: 0.11099529266357422 MB
# memory in use for the chunk is: 0.11008167266845703 MB
# memory in use for the chunk is: 0.10877132415771484 MB
# memory in use for the chunk is: 0.10917854309082031 MB
# memory in use for the chunk is: 0.10936737060546875 MB
# memory in use for the chunk is: 0.10914230346679688 MB
# memory in use for the chunk is: 0.10982322692871094 MB
# memory in use for the chunk is: 0.11018180847167969 MB
# memory in use for the chunk is: 0.11011219024658203 MB
# memory in use for the chunk is: 0.10963153839111328 MB
# memory in use for the chunk is: 0.10901165008544922 MB
# memory in use for the chunk is: 0.10860538482666016 MB
# memory in use for the chunk is: 0.10913658142089844 MB
# memory in use for the chunk is: 0.10799407958984375 MB
# memory in use for the chunk is: 0.10827064514160156 MB
# memory in use for the chunk is: 0.10875225067138672 MB
# memory in use for the chunk is: 0.11031341552734375 MB
# memory in use for the chunk is: 0.10668563842773438 MB
# memory in use for the chunk is: 0.11042404174804688 MB
# memory in use for the chunk is: 0.11017990112304688 MB
# memory in use for the chunk is: 0.11119556427001953 MB
# memory in use for the chunk is: 0.1113271713256836 MB
# memory in use for the chunk is: 0.10860729217529297 MB
# memory in use for the chunk is: 0.10978031158447266 MB
# memory in use for the chunk is: 0.10844898223876953 MB
# memory in use for the chunk is: 0.11013031005859375 MB
# memory in use for the chunk is: 0.10634040832519531 MB
# memory in use for the chunk is: 0.10801219940185547 MB
# memory in use for the chunk is: 0.10756301879882812 MB
# memory in use for the chunk is: 0.10955524444580078 MB
# memory in use for the chunk is: 0.1089935302734375 MB
# memory in use for the chunk is: 0.10768699645996094 MB
# memory in use for the chunk is: 0.10332965850830078 MB
# memory in use for the chunk is: 0.10805130004882812 MB
# memory in use for the chunk is: 0.10861682891845703 MB
# memory in use for the chunk is: 0.10864543914794922 MB
# memory in use for the chunk is: 0.11137866973876953 MB
# memory in use for the chunk is: 0.11101055145263672 MB
# memory in use for the chunk is: 0.10935211181640625 MB
# memory in use for the chunk is: 0.10947895050048828 MB
# memory in use for the chunk is: 0.10902976989746094 MB
# memory in use for the chunk is: 0.11063575744628906 MB
# memory in use for the chunk is: 0.11083030700683594 MB
# memory in use for the chunk is: 0.11029052734375 MB
# memory in use for the chunk is: 0.10887527465820312 MB
# memory in use for the chunk is: 0.10874080657958984 MB
# memory in use for the chunk is: 0.10731124877929688 MB
# memory in use for the chunk is: 0.10687255859375 MB
# memory in use for the chunk is: 0.10919189453125 MB
# memory in use for the chunk is: 0.108551025390625 MB
# memory in use for the chunk is: 0.11137676239013672 MB
# memory in use for the chunk is: 0.10838794708251953 MB
# memory in use for the chunk is: 0.108489990234375 MB
# memory in use for the chunk is: 0.10859489440917969 MB
# memory in use for the chunk is: 0.10856056213378906 MB
# memory in use for the chunk is: 0.10932254791259766 MB
# memory in use for the chunk is: 0.10827922821044922 MB
# memory in use for the chunk is: 0.10746574401855469 MB
# memory in use for the chunk is: 0.11275482177734375 MB
# memory in use for the chunk is: 0.11238479614257812 MB
# memory in use for the chunk is: 0.11234760284423828 MB
# memory in use for the chunk is: 0.11174201965332031 MB
# memory in use for the chunk is: 0.10921764373779297 MB
# memory in use for the chunk is: 0.109130859375 MB
# memory in use for the chunk is: 0.10922431945800781 MB
# memory in use for the chunk is: 0.10939693450927734 MB
# memory in use for the chunk is: 0.10927867889404297 MB
# memory in use for the chunk is: 0.10881328582763672 MB
# memory in use for the chunk is: 0.10930538177490234 MB
# memory in use for the chunk is: 0.10883808135986328 MB
# memory in use for the chunk is: 0.11159324645996094 MB
# memory in use for the chunk is: 0.11173343658447266 MB
# memory in use for the chunk is: 0.10988903045654297 MB
# memory in use for the chunk is: 0.11007404327392578 MB
# memory in use for the chunk is: 0.10847282409667969 MB
# memory in use for the chunk is: 0.1087503433227539 MB
# memory in use for the chunk is: 0.10916709899902344 MB
# memory in use for the chunk is: 0.10955238342285156 MB
# memory in use for the chunk is: 0.11040306091308594 MB
# memory in use for the chunk is: 0.10927486419677734 MB
# memory in use for the chunk is: 0.10878753662109375 MB
# memory in use for the chunk is: 0.10828113555908203 MB
# memory in use for the chunk is: 0.10915088653564453 MB
# memory in use for the chunk is: 0.1096658706665039 MB
# memory in use for the chunk is: 0.10957717895507812 MB
# memory in use for the chunk is: 0.10949993133544922 MB
# memory in use for the chunk is: 0.10966300964355469 MB
# memory in use for the chunk is: 0.10921192169189453 MB
# memory in use for the chunk is: 0.10940265655517578 MB
# memory in use for the chunk is: 0.10937690734863281 MB
# memory in use for the chunk is: 0.11052513122558594 MB
# memory in use for the chunk is: 0.1109771728515625 MB
# memory in use for the chunk is: 0.10896492004394531 MB
# memory in use for the chunk is: 0.10872840881347656 MB
# memory in use for the chunk is: 0.10551834106445312 MB
# memory in use for the chunk is: 0.10973644256591797 MB
# memory in use for the chunk is: 0.11032485961914062 MB
# memory in use for the chunk is: 0.1109609603881836 MB
# memory in use for the chunk is: 0.11107349395751953 MB
# memory in use for the chunk is: 0.10820674896240234 MB
# memory in use for the chunk is: 0.1104116439819336 MB
# memory in use for the chunk is: 0.10852241516113281 MB
# memory in use for the chunk is: 0.10925483703613281 MB
# memory in use for the chunk is: 0.11034011840820312 MB
# memory in use for the chunk is: 0.11161422729492188 MB
# memory in use for the chunk is: 0.11169815063476562 MB
# memory in use for the chunk is: 0.1113290786743164 MB
# memory in use for the chunk is: 0.1114664077758789 MB
# memory in use for the chunk is: 0.11137104034423828 MB
# memory in use for the chunk is: 0.10945415496826172 MB
# memory in use for the chunk is: 0.1103658676147461 MB
# memory in use for the chunk is: 0.10927200317382812 MB
# memory in use for the chunk is: 0.10869979858398438 MB
# memory in use for the chunk is: 0.11015987396240234 MB
# memory in use for the chunk is: 0.1117715835571289 MB
# memory in use for the chunk is: 0.11175060272216797 MB
# memory in use for the chunk is: 0.10918617248535156 MB
# memory in use for the chunk is: 0.11034107208251953 MB
# memory in use for the chunk is: 0.11118602752685547 MB
# memory in use for the chunk is: 0.11078834533691406 MB
# memory in use for the chunk is: 0.1084280014038086 MB
# memory in use for the chunk is: 0.10793781280517578 MB
# memory in use for the chunk is: 0.11017036437988281 MB
# memory in use for the chunk is: 0.11111736297607422 MB
# memory in use for the chunk is: 0.10860443115234375 MB
# memory in use for the chunk is: 0.10856819152832031 MB
# memory in use for the chunk is: 0.10961341857910156 MB
# memory in use for the chunk is: 0.10913944244384766 MB
# memory in use for the chunk is: 0.10988903045654297 MB
# memory in use for the chunk is: 0.11024665832519531 MB
# memory in use for the chunk is: 0.1108083724975586 MB
# memory in use for the chunk is: 0.11034965515136719 MB
# memory in use for the chunk is: 0.11032581329345703 MB
# memory in use for the chunk is: 0.10909080505371094 MB
# memory in use for the chunk is: 0.10889053344726562 MB
# memory in use for the chunk is: 0.10964107513427734 MB
# memory in use for the chunk is: 0.11014175415039062 MB
# memory in use for the chunk is: 0.10927295684814453 MB
# memory in use for the chunk is: 0.10931968688964844 MB
# memory in use for the chunk is: 0.11015796661376953 MB
# memory in use for the chunk is: 0.10943126678466797 MB
# memory in use for the chunk is: 0.11028480529785156 MB
# memory in use for the chunk is: 0.11106109619140625 MB
# memory in use for the chunk is: 0.10941696166992188 MB
# memory in use for the chunk is: 0.10947895050048828 MB
# memory in use for the chunk is: 0.109161376953125 MB
# memory in use for the chunk is: 0.10778331756591797 MB
# memory in use for the chunk is: 0.11010456085205078 MB
# memory in use for the chunk is: 0.10949230194091797 MB
# memory in use for the chunk is: 0.10899162292480469 MB
# memory in use for the chunk is: 0.1066732406616211 MB
# memory in use for the chunk is: 0.10791301727294922 MB
# memory in use for the chunk is: 0.11001110076904297 MB
# memory in use for the chunk is: 0.10963916778564453 MB
# memory in use for the chunk is: 0.10934162139892578 MB
# memory in use for the chunk is: 0.1093912124633789 MB
# memory in use for the chunk is: 0.11008930206298828 MB
# memory in use for the chunk is: 0.10909080505371094 MB
# memory in use for the chunk is: 0.10982418060302734 MB
# memory in use for the chunk is: 0.10938644409179688 MB
# memory in use for the chunk is: 0.10863876342773438 MB
# memory in use for the chunk is: 0.10860443115234375 MB
# memory in use for the chunk is: 0.10789108276367188 MB
# memory in use for the chunk is: 0.10882091522216797 MB
# memory in use for the chunk is: 0.1084585189819336 MB
# memory in use for the chunk is: 0.10848045349121094 MB
# memory in use for the chunk is: 0.10954952239990234 MB
# memory in use for the chunk is: 0.10793876647949219 MB
# memory in use for the chunk is: 0.1104745864868164 MB
# memory in use for the chunk is: 0.10854530334472656 MB
# memory in use for the chunk is: 0.10940170288085938 MB
# memory in use for the chunk is: 0.1091318130493164 MB
# memory in use for the chunk is: 0.1097412109375 MB
# memory in use for the chunk is: 0.10920333862304688 MB
# memory in use for the chunk is: 0.10926055908203125 MB
# memory in use for the chunk is: 0.10862445831298828 MB
# memory in use for the chunk is: 0.1091461181640625 MB
# memory in use for the chunk is: 0.10928058624267578 MB
# memory in use for the chunk is: 0.10865402221679688 MB
# memory in use for the chunk is: 0.10959815979003906 MB
# memory in use for the chunk is: 0.10868358612060547 MB
# memory in use for the chunk is: 0.10883235931396484 MB
# memory in use for the chunk is: 0.10967826843261719 MB
# memory in use for the chunk is: 0.11025524139404297 MB
# memory in use for the chunk is: 0.10763359069824219 MB
# memory in use for the chunk is: 0.10954952239990234 MB
# memory in use for the chunk is: 0.1090230941772461 MB
# memory in use for the chunk is: 0.10918521881103516 MB
# memory in use for the chunk is: 0.10807418823242188 MB
# memory in use for the chunk is: 0.10845661163330078 MB
# memory in use for the chunk is: 0.10871315002441406 MB
# memory in use for the chunk is: 0.10875225067138672 MB
# memory in use for the chunk is: 0.11012649536132812 MB
# memory in use for the chunk is: 0.10906314849853516 MB
# memory in use for the chunk is: 0.10777568817138672 MB
# memory in use for the chunk is: 0.10482215881347656 MB
# memory in use for the chunk is: 0.10982799530029297 MB
# memory in use for the chunk is: 0.10927677154541016 MB
# memory in use for the chunk is: 0.10852527618408203 MB
# memory in use for the chunk is: 0.1097412109375 MB
# memory in use for the chunk is: 0.11019611358642578 MB
# memory in use for the chunk is: 0.10778522491455078 MB
# memory in use for the chunk is: 0.10787105560302734 MB
# memory in use for the chunk is: 0.10800361633300781 MB
# memory in use for the chunk is: 0.10794925689697266 MB
# memory in use for the chunk is: 0.10920906066894531 MB
# memory in use for the chunk is: 0.1085653305053711 MB
# memory in use for the chunk is: 0.10785675048828125 MB
# memory in use for the chunk is: 0.10886859893798828 MB
# memory in use for the chunk is: 0.10985088348388672 MB
# memory in use for the chunk is: 0.1097564697265625 MB
# memory in use for the chunk is: 0.10931777954101562 MB
# memory in use for the chunk is: 0.1096811294555664 MB
# memory in use for the chunk is: 0.10901641845703125 MB
# memory in use for the chunk is: 0.10931015014648438 MB
# memory in use for the chunk is: 0.10956859588623047 MB
# memory in use for the chunk is: 0.11126708984375 MB
# memory in use for the chunk is: 0.109893798828125 MB
# memory in use for the chunk is: 0.10898876190185547 MB
# memory in use for the chunk is: 0.10926151275634766 MB
# memory in use for the chunk is: 0.10901165008544922 MB
# memory in use for the chunk is: 0.10901451110839844 MB
# memory in use for the chunk is: 0.11098575592041016 MB
# memory in use for the chunk is: 0.10939693450927734 MB
# memory in use for the chunk is: 0.10953998565673828 MB
# memory in use for the chunk is: 0.10872459411621094 MB
# memory in use for the chunk is: 0.10846328735351562 MB
# memory in use for the chunk is: 0.10890388488769531 MB
# memory in use for the chunk is: 0.10841751098632812 MB
# memory in use for the chunk is: 0.10897445678710938 MB
# memory in use for the chunk is: 0.11004638671875 MB
# memory in use for the chunk is: 0.1097726821899414 MB
# memory in use for the chunk is: 0.10998153686523438 MB
# memory in use for the chunk is: 0.11058425903320312 MB
# memory in use for the chunk is: 0.10959243774414062 MB
# memory in use for the chunk is: 0.10979557037353516 MB
# memory in use for the chunk is: 0.11139488220214844 MB
# memory in use for the chunk is: 0.1074209213256836 MB
# memory in use for the chunk is: 0.10808849334716797 MB
# memory in use for the chunk is: 0.10852241516113281 MB
# memory in use for the chunk is: 0.10871410369873047 MB
# memory in use for the chunk is: 0.10948848724365234 MB
# memory in use for the chunk is: 0.10920906066894531 MB
# memory in use for the chunk is: 0.1083669662475586 MB
# memory in use for the chunk is: 0.10844612121582031 MB
# memory in use for the chunk is: 0.10960102081298828 MB
# memory in use for the chunk is: 0.10950946807861328 MB
# memory in use for the chunk is: 0.109283447265625 MB
# memory in use for the chunk is: 0.10353374481201172 MB
# memory in use for the chunk is: 0.10866355895996094 MB
# memory in use for the chunk is: 0.10973548889160156 MB
# memory in use for the chunk is: 0.10938358306884766 MB
# memory in use for the chunk is: 0.10995197296142578 MB
# memory in use for the chunk is: 0.10835456848144531 MB
# memory in use for the chunk is: 0.1086893081665039 MB
# memory in use for the chunk is: 0.1075439453125 MB
# memory in use for the chunk is: 0.09023284912109375 MB
# memory in use for the chunk is: 0.09038162231445312 MB
# memory in use for the chunk is: 0.09059619903564453 MB
# memory in use for the chunk is: 0.09050178527832031 MB
# memory in use for the chunk is: 0.09042072296142578 MB
# memory in use for the chunk is: 0.09055137634277344 MB
# memory in use for the chunk is: 0.09035110473632812 MB
# memory in use for the chunk is: 0.09032630920410156 MB
# memory in use for the chunk is: 0.09027385711669922 MB
# memory in use for the chunk is: 0.09009265899658203 MB
# memory in use for the chunk is: 0.09043312072753906 MB
# memory in use for the chunk is: 0.09039306640625 MB
# memory in use for the chunk is: 0.09059619903564453 MB
# memory in use for the chunk is: 0.0904998779296875 MB
# memory in use for the chunk is: 0.09026145935058594 MB
# memory in use for the chunk is: 0.0909423828125 MB
# memory in use for the chunk is: 0.09048175811767578 MB
# memory in use for the chunk is: 0.090423583984375 MB
# memory in use for the chunk is: 0.09003353118896484 MB
# memory in use for the chunk is: 0.0901479721069336 MB
# memory in use for the chunk is: 0.09036064147949219 MB
# memory in use for the chunk is: 0.09003925323486328 MB
# memory in use for the chunk is: 0.09033489227294922 MB
# memory in use for the chunk is: 0.09047698974609375 MB
# memory in use for the chunk is: 0.09041118621826172 MB
# memory in use for the chunk is: 0.09011459350585938 MB
# memory in use for the chunk is: 0.09020614624023438 MB
# memory in use for the chunk is: 0.0904998779296875 MB
# memory in use for the chunk is: 0.09077739715576172 MB
# memory in use for the chunk is: 0.09041690826416016 MB
# memory in use for the chunk is: 0.09046649932861328 MB
# memory in use for the chunk is: 0.09031200408935547 MB
# memory in use for the chunk is: 0.09042930603027344 MB
# memory in use for the chunk is: 0.09061431884765625 MB
# memory in use for the chunk is: 0.09054279327392578 MB
# memory in use for the chunk is: 0.09062957763671875 MB
# memory in use for the chunk is: 0.09049701690673828 MB
# memory in use for the chunk is: 0.0901346206665039 MB
# memory in use for the chunk is: 0.09004020690917969 MB
# memory in use for the chunk is: 0.09054851531982422 MB
# memory in use for the chunk is: 0.090484619140625 MB
# memory in use for the chunk is: 0.0902090072631836 MB
# memory in use for the chunk is: 0.09013748168945312 MB
# memory in use for the chunk is: 0.09020614624023438 MB
# memory in use for the chunk is: 0.09084033966064453 MB
# memory in use for the chunk is: 0.09062767028808594 MB
# memory in use for the chunk is: 0.09067249298095703 MB
# memory in use for the chunk is: 0.09031200408935547 MB
# memory in use for the chunk is: 0.09034347534179688 MB
# memory in use for the chunk is: 0.090667724609375 MB
# memory in use for the chunk is: 0.09061717987060547 MB
# memory in use for the chunk is: 0.09053230285644531 MB
# memory in use for the chunk is: 0.090484619140625 MB
# memory in use for the chunk is: 0.09026050567626953 MB
# memory in use for the chunk is: 0.09026813507080078 MB
# memory in use for the chunk is: 0.0903615951538086 MB
# memory in use for the chunk is: 0.0904693603515625 MB
# memory in use for the chunk is: 0.09085559844970703 MB
# memory in use for the chunk is: 0.0908823013305664 MB
# memory in use for the chunk is: 0.09054851531982422 MB
# memory in use for the chunk is: 0.09027481079101562 MB
# memory in use for the chunk is: 0.09046649932861328 MB
# memory in use for the chunk is: 0.09071063995361328 MB
# memory in use for the chunk is: 0.09025859832763672 MB
# memory in use for the chunk is: 0.09040260314941406 MB
# memory in use for the chunk is: 0.09038925170898438 MB
# memory in use for the chunk is: 0.09030342102050781 MB
# memory in use for the chunk is: 0.09076976776123047 MB
# memory in use for the chunk is: 0.09054946899414062 MB
# memory in use for the chunk is: 0.09049224853515625 MB
# memory in use for the chunk is: 0.09051990509033203 MB
# memory in use for the chunk is: 0.08994007110595703 MB
# memory in use for the chunk is: 0.09051322937011719 MB
# memory in use for the chunk is: 0.09004592895507812 MB
# memory in use for the chunk is: 0.09032154083251953 MB
# memory in use for the chunk is: 0.09026145935058594 MB
# memory in use for the chunk is: 0.09050464630126953 MB
# memory in use for the chunk is: 0.09029769897460938 MB
# memory in use for the chunk is: 0.09037017822265625 MB
# memory in use for the chunk is: 0.09073638916015625 MB
# memory in use for the chunk is: 0.0906362533569336 MB
# memory in use for the chunk is: 0.0907583236694336 MB
# memory in use for the chunk is: 0.09049606323242188 MB
# memory in use for the chunk is: 0.09049606323242188 MB
# memory in use for the chunk is: 0.09029769897460938 MB
# memory in use for the chunk is: 0.09027481079101562 MB
# memory in use for the chunk is: 0.09080314636230469 MB
# memory in use for the chunk is: 0.09055423736572266 MB
# memory in use for the chunk is: 0.09056854248046875 MB
# memory in use for the chunk is: 0.06333732604980469 MB
# memory usage: 56.14124393463135 MB

# %%
# Making changes to ensure overall memory stays under 10 megabytes.

import pandas as pd

# Read the CSV file in chunks of 1000 rows
augment_df = pd.read_csv("https://bit.ly/3BPcobU", chunksize=1000, encoding='unicode_escape')

# Initialize an empty list to store the records
records = []

# Keep track of the total memory usage
memory_usage = 0

# Iterate over the chunks
for chunk in augment_df:
    # Select only the columns with object dtype
    text_cols = chunk.select_dtypes(include='object')
    
    # Sample 1000 rows from the text columns
    samples = text_cols.sample(1000)
    
    # Append the samples to the records list
    records.append(samples)
    
    # Update the total memory usage
    memory_usage += samples.memory_usage(deep=True).sum()/2**20
    
    # If the total memory usage exceeds 10 MB, break the loop
    if memory_usage > 10:
        break

# Concatenate the records into a single DataFrame
final_df = pd.concat(records)

# Print the total memory usage
print(f'Overall consumption is {memory_usage} Mbs')
# Out:
# Overall consumption is 10.96226692199707 Mbs

# %% [markdown]
# #Finding
# The memory usage is now 10.96mb down from 56mb.

# %% [markdown]
# ## Question 3: Loading Chunks Into SQLite

# %% [markdown]
# Now we're in good shape to start exploring and analyzing the data. The next step is to load each chunk into a table in a SQLite database so we can query the full data set.
#
# **Tasks**
#
# 1. Create and connect to a new SQLite database file.
# 2. Expand on the existing chunk processing code to export each chunk to a new table in the SQLite database.
# 3. Query the table and make sure the data types match up to what you had in mind for each column.

# %%
# Create and connect to a new SQLite database file.
conn = sqlite3.connect("funding.db")
augment_df = pd.read_csv("https://bit.ly/3BPcobU", chunksize=1000,encoding = 'unicode_escape')
for chunk in augment_df:
    chunk.to_sql("funding", conn, if_exists='append', index=False)
    df = pd.read_sql('PRAGMA table_info(funding);', conn)
print(df)
# Out:
#     cid                    name     type  notnull dflt_value  pk
# 0     0       company_permalink     TEXT        0       None   0
# 1     1            company_name     TEXT        0       None   0
# 2     2   company_category_code     TEXT        0       None   0
# 3     3    company_country_code     TEXT        0       None   0
# 4     4      company_state_code     TEXT        0       None   0
# 5     5          company_region     TEXT        0       None   0
# 6     6            company_city     TEXT        0       None   0
# 7     7      investor_permalink     TEXT        0       None   0
# 8     8           investor_name     TEXT        0       None   0
# 9     9  investor_category_code     TEXT        0       None   0
# 10   10   investor_country_code     TEXT        0       None   0
# 11   11     investor_state_code     TEXT        0       None   0
# 12   12         investor_region     TEXT        0       None   0
# 13   13           investor_city     TEXT        0       None   0
# 14   14      funding_round_type     TEXT        0       None   0
# 15   15               funded_at     TEXT        0       None   0
# 16   16            funded_month     TEXT        0       None   0
# 17   17          funded_quarter     TEXT        0       None   0
# 18   18             funded_year  INTEGER        0       None   0
# 19   19       raised_amount_usd     REAL        0       None   0

# %%
#
# Create a cursor object
cursor = conn.cursor()

# Query the table
cursor.execute("PRAGMA table_info(funding)")

# Get the column names and types
columns = cursor.fetchall()
for column in columns:
  print(column[1], column[2])
# Out:
# company_permalink TEXT
# company_name TEXT
# company_category_code TEXT
# company_country_code TEXT
# company_state_code TEXT
# company_region TEXT
# company_city TEXT
# investor_permalink TEXT
# investor_name TEXT
# investor_category_code TEXT
# investor_country_code TEXT
# investor_state_code TEXT
# investor_region TEXT
# investor_city TEXT
# funding_round_type TEXT
# funded_at TEXT
# funded_month TEXT
# funded_quarter TEXT
# funded_year INTEGER
# raised_amount_usd REAL

# %%
# Query the table and make sure the data types match up to what you had in mind for each column.
outcome_df = pd.read_sql('PRAGMA table_info(funding);', conn)
print(outcome_df)
# Out:
#     cid                    name     type  notnull dflt_value  pk
# 0     0       company_permalink     TEXT        0       None   0
# 1     1            company_name     TEXT        0       None   0
# 2     2   company_category_code     TEXT        0       None   0
# 3     3    company_country_code     TEXT        0       None   0
# 4     4      company_state_code     TEXT        0       None   0
# 5     5          company_region     TEXT        0       None   0
# 6     6            company_city     TEXT        0       None   0
# 7     7      investor_permalink     TEXT        0       None   0
# 8     8           investor_name     TEXT        0       None   0
# 9     9  investor_category_code     TEXT        0       None   0
# 10   10   investor_country_code     TEXT        0       None   0
# 11   11     investor_state_code     TEXT        0       None   0
# 12   12         investor_region     TEXT        0       None   0
# 13   13           investor_city     TEXT        0       None   0
# 14   14      funding_round_type     TEXT        0       None   0
# 15   15               funded_at     TEXT        0       None   0
# 16   16            funded_month     TEXT        0       None   0
# 17   17          funded_quarter     TEXT        0       None   0
# 18   18             funded_year  INTEGER        0       None   0
# 19   19       raised_amount_usd     REAL        0       None   0

# %%
df = pd.read_sql("SELECT * FROM funding LIMIT 5", conn)
df
# Out:
#      company_permalink company_name company_category_code  \
# 0    /company/advercar     AdverCar           advertising
# 1  /company/launchgram   LaunchGram                  news
# 2        /company/utap         uTaP             messaging
# 3    /company/zoopshop     ZoopShop              software
# 4    /company/efuneral     eFuneral                   web
#
#   company_country_code company_state_code         company_region  \
# 0                  USA                 CA                 SF Bay
# 1                  USA                 CA                 SF Bay
# 2                  USA               None  United States - Other
# 3                  USA                 OH               Columbus
# 4                  USA                 OH              Cleveland
#
#     company_city          investor_permalink      investor_name  \
# 0  San Francisco  /company/1-800-flowers-com  1-800-FLOWERS.COM
# 1  Mountain View        /company/10xelerator        10Xelerator
# 2           None        /company/10xelerator        10Xelerator
# 3       columbus        /company/10xelerator        10Xelerator
# 4      Cleveland        /company/10xelerator        10Xelerator
#
#   investor_category_code investor_country_code investor_state_code  \
# 0                   None                   USA                  NY
# 1                finance                   USA                  OH
# 2                finance                   USA                  OH
# 3                finance                   USA                  OH
# 4                finance                   USA                  OH
#
#   investor_region investor_city funding_round_type   funded_at funded_month  \
# 0        New York      New York           series-a  2012-10-30      2012-10
# 1        Columbus      Columbus              other  2012-01-23      2012-01
# 2        Columbus      Columbus              other  2012-01-01      2012-01
# 3        Columbus      Columbus              angel  2012-02-15      2012-02
# 4        Columbus      Columbus              other  2011-09-08      2011-09
#
#   funded_quarter  funded_year  raised_amount_usd
# 0        2012-Q4         2012          2000000.0
# 1        2012-Q1         2012            20000.0
# 2        2012-Q1         2012            20000.0
# 3        2012-Q1         2012            20000.0
# 4        2011-Q3         2011            20000.0

# %% [markdown]
# # conclusion.
# data is stored in our desired formart in an sql format

# %% [markdown]
# ## Question 4: Next Steps

# %% [markdown]
# Now that the data is in SQLite, we can use the pandas SQLite workflow we learned in the last lesson to explore and analyze startup investments. Remember that each row isn't a unique company, but a unique investment from a single investor. This means that many startups will span multiple rows.
#
# Use the pandas SQLite workflow to answer the following questions:
#
# * What proportion of the total amount of funds did the top 10% raise? What about the top 1%? Compare these values to the proportions the bottom 10% and bottom 1% raised.
# * Which category of company attracted the most investments?
# * Which investor contributed the most money (across all startups)?
# * Which investors contributed the most money per startup?
# * Which funding round was the most popular? Which was the least popular?
#
# Here are some ideas for further exploration:
#
# * Repeat the tasks in this project using stricter memory constraints (under 1 megabyte).
# * Clean and analyze the other Crunchbase data sets from the same GitHub repo.
# * Understand which columns the data sets share, and how the data sets are linked.
# * Create a relational database design that links the data sets together and reduces the overall disk space the database file consumes.
#
# Use pandas to populate each table in the database, create the appropriate indexes, and so on.

# %%
# Your code goes here
# What proportion of the total amount of funds did the top 10% raise? What about the top 1%? 
# Compare these values to the proportions the bottom 10% and bottom 1% raised.

df = pd.read_sql("SELECT * FROM funding", conn)
group_df = df.groupby("company_name").sum()
sort_df= group_df.sort_values("raised_amount_usd", ascending=False)
total_funds = sort_df["raised_amount_usd"].sum()

# proportion of funds raised by the top 10%
top_10 = sort_df.iloc[:int(len(sort_df) * 0.1)]["raised_amount_usd"].sum()
top_10_proportion = top_10 / total_funds

# proportion of funds raised by the top 1%
top_1 = sort_df.iloc[:int(len(sort_df) * 0.01)]["raised_amount_usd"].sum()
top_1_proportion = top_1 / total_funds

# Output of the expectation

print("Proportion of total funds raised by top 10% is:", top_10_proportion)
print("Proportion of total funds raised by top 1%:", top_1_proportion)
# Out:
# Proportion of total funds raised by top 10% is: 0.6712772709906496
# Proportion of total funds raised by top 1%: 0.26217737281766545

# %%
# comparing values of top 10%, 1% and values of bottom 10% and 1%
bottom_10 = sort_df.iloc[-int(len(sort_df) * 0.1):]["raised_amount_usd"].sum()
bottom_10_proportion = bottom_10 / total_funds

bottom_1 = sort_df.iloc[-int(len(sort_df) * 0.01):]["raised_amount_usd"].sum()
bottom_1_proportion = bottom_1 / total_funds

# output of expectation

print("bottom 10%'s proportion of funds raised:", bottom_10)
print("bottom 1%'s proportion of funds raised:", bottom_1_proportion)
# Out:
# bottom 10%'s proportion of funds raised: 0.0
# bottom 1%'s proportion of funds raised: 0.0

# %%
# To check which category of companies attracted the most investment, do the following;
most_ivestments_df = df.groupby("company_category_code").sum()
most_ivestments_df_sorted = most_ivestments_df.sort_values("raised_amount_usd", ascending=False)
category_most_invested = most_ivestments_df_sorted.index[0]

# output the results
print("Company category that attracted the most investments is:", category_most_invested)
# Out:
# Company category that attracted the most investments is: biotech

# %%
# To get the investor that contributed alot across all startups
most_ivestments_df = df.groupby("investor_name").sum()
most_ivestments_df_sorted = most_ivestments_df.sort_values("raised_amount_usd", ascending=False)
investor_most_contributor = most_ivestments_df_sorted.index[0]

# Output the findings
print("most money contributed came from:", investor_most_contributor)
# Out:
# most money contributed came from: Kleiner Perkins Caufield & Byers

# %%
# to get investors that contributed the most per start up
most_ivestments_df = df.groupby(["company_name","investor_name"]).agg({"raised_amount_usd": "sum"})
most_ivestments_df_sorted = most_ivestments_df.sort_values("raised_amount_usd", ascending=False)
first_10_investors = most_ivestments_df_sorted.head(10)
print(first_10_investors)
# Out:
#                                        raised_amount_usd
# company_name investor_name
# Clearwire    Time Warner                    5.620000e+09
#              Comcast                        5.620000e+09
#              Intel                          5.620000e+09
#              BrightHouse                    4.700000e+09
#              Google                         3.200000e+09
# sigmacare    Marlin Equity Partners         2.600000e+09
# Clearwire    Sprint Nextel                  2.500000e+09
#              Eagle River Holdings           2.420000e+09
# Facebook     Digital Sky Technologies       1.700000e+09
#              Goldman Sachs                  1.500000e+09

# %%
# Create a relational database design that links the data sets together and reduces the overall disk space the database file consumes.

most_ivestments_df = df.groupby("funding_round_type").count()
most_ivestments_df_sorted = most_ivestments_df.sort_values("company_name", ascending=False)
most_popular_round = most_ivestments_df_sorted.index[0]
least_popular_round = most_ivestments_df_sorted.index[-1]

# output the finding
print("The most popular funding round is:", most_popular_round)
print("The least popular funding round is:", least_popular_round)

# It is a good practice to close the connection after you are done using it.
conn.close()
# Out:
# The most popular funding round is: series-a
# The least popular funding round is: crowdfunding
